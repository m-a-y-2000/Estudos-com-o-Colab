# %%
peso = float(input("Digite o seu peso: "))
altura = float(input("Digite sua altura: "))

imc = peso/(altura*altura)

print("Seu IMC é: ", imc)
# Out:
# Digite o seu peso: 80
# Digite sua altura: 1.80
# Seu IMC é:  24.691358024691358
