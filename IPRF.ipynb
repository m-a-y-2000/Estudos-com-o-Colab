# %%
def IPRF(ren, her, doa, pat):

  if ren > 15.764 or her > 40.000 or doa > 40.000 or pat > 80.000:
    print("Precisa declarar.")
  else:
    print("Não precisa declarar.")

# %%
IPRF(15.765, 0, 0, 0)
# Out:
# Precisa declarar.
